# %%
# Generate data for the Darcy flow problem
# Input: a - the permeability "ground truth"
# output: u - the flow through the permeability
# data generated:
# 2 datasets of 200 'Devito' pairs, to compare with the ground truth, with resolutions of:
# 128, 64

# %%
pip install torch

# %%
pip install tensorflow

# %%
import torch
import math
from devito import div, grad, Eq, Operator, TimeFunction, Function, solve, Grid, configuration
import numpy as np
from random_fields import GaussianRF
from timeit import default_timer
import scipy.io
# Out:
# 2022-08-29 17:21:20.688714: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-29 17:21:20.688775: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import os

# %%
os.environ['DEVITO_LANGUAGE'] = 'openmp'

os.environ['OMP_SCHEDULE'] = 'STATIC'

os.environ['OMP_PROC_BIND'] = 'true'

os.environ['OMP_PLACES'] = 'cores'

# %%
'''
function to generate 'u' from 'a' using Devito
parameters 
-----------------
perm: tensor of size (1, s, s)
    this is "a"
f: tensor of size (s, s)
    the forcing function f(x) = 1
s: int
    the resolution
 '''
def darcy_flow_2d(perm, f, s):
    
    # a(x) is the coefficients
    # f is the forcing function
    # give the a and f1 functions the same data as inputs perm and f
    for i in range(s):
        f1.data[i] = f[i]
        a.data[i] = perm[i]
    
    # call operator for the nth psuedo-timestep
    if s == 128:
        n = 7500
    else:
        n = 3750
    
    op(time=n)
   
    return torch. from_numpy(u.data[0])

# %%
# Silence the runtime performance logging
configuration['log-level'] = 'ERROR'

# this is used to generate "devito" data results, to compare to the FNO results and the ground truth

# Use the inputs from the ground truth to generate new outputs to compare
test_128 = scipy.io.loadmat('df_test_128.mat') 
test_64 = scipy.io.loadmat('df_test_64.mat') 

# for each test mat file:
for testcase in [test_128, test_64]:
   
    # number of grid points on [0,1]^2 
    s = testcase['coeff'].shape[1]
    print("this is s", s)
    
    # Number of solutions to generate
    N = 200

    # Forcing function, f(x) = 1 
    f = np.ones((s, s))

    # create s x s grid with spacing 1
    grid = Grid(shape=(s, s), extent=(1.0,1.0))

    # create function on grid
    # space order of 2 to enable 2nd derivative
    # TimeFunction for u can be used despite the lack of a time-dependence. This is done for psuedotime
    u = TimeFunction(name='u', grid=grid, space_order=2)
    a = Function(name='a', grid=grid, space_order=2)
    f1 = Function(name='f1', grid=grid, space_order=2)

    # define 2D Darcy flow equation
    equation_u = Eq(-a*u.laplace,f1)

    # Let SymPy solve for the central stencil point
    stencil = solve(equation_u, u)

    # Let our stencil populate the buffer `u.forward`
    update = Eq(u.forward, stencil)

    # Boundary Conds
    x, y = grid.dimensions
    t = grid.stepping_dim
    nx = s
    ny = s
    bc = [Eq(u[t+1, 0, y],u[t+1, 1,y])]  # du/dx = 0 for x=0.
    bc += [Eq(u[t+1,nx-1, y],u[t+1,nx-2, y])]  # du/dx = 0 for x=1.
    bc += [Eq(u[t+1, x, 0],u[t+1,x ,1])]  # du/dx = 0 at y=0
    bc += [Eq(u[t+1, x, ny-1],u[t+1, x, ny-2])]  # du/dx=0 for y=1
    # u=0 for all sides
    bc = [Eq(u[t+1, x, 0], 0.)]
    bc += [Eq(u[t+1, x, ny-1], 0.)]
    bc += [Eq(u[t+1, 0, y], 0.)]
    bc += [Eq(u[t+1, nx-1, y], 0.)]

    op = Operator([update] + bc)


    # all the inputs
    coeff = np.zeros(shape=(N, s, s))
    #all the solutions
    sol = torch.zeros(N, s, s)
     
    c = 0
    t0 = default_timer()
    
    # for each input generate a new solution
    for each_input in testcase['coeff']:
        
        w1 = each_input
        
        #Solve df
        output = darcy_flow_2d(w1, f, s)
        
        coeff[c:(c+1),...] = w1
        sol[c:(c+1),...] = output
        
        c += 1
        t1 = default_timer()
        print("sample no. :", c, "Time taken:", t1-t0)
    
    scipy.io.savemat('df_devito_{}.mat'.format(s), mdict={'coeff': coeff, 'sol': sol.cpu().numpy()})
# Out:
# this is s 128
# sample no. : 1 Time taken: 0.40384356025606394
# sample no. : 2 Time taken: 0.5324056725949049
# sample no. : 3 Time taken: 0.651508585549891
# sample no. : 4 Time taken: 0.7701763212680817
# sample no. : 5 Time taken: 0.8913664072751999
# sample no. : 6 Time taken: 1.0228362949565053
# sample no. : 7 Time taken: 1.150304819457233
# sample no. : 8 Time taken: 1.2821287848055363
# sample no. : 9 Time taken: 1.402497736737132
# sample no. : 10 Time taken: 1.5271877311170101
# sample no. : 11 Time taken: 1.646625217050314
# sample no. : 12 Time taken: 1.7668254980817437
# sample no. : 13 Time taken: 1.8860299428924918
# sample no. : 14 Time taken: 2.007365363650024
# sample no. : 15 Time taken: 2.1288217278197408
# sample no. : 16 Time taken: 2.2501185182482004
# sample no. : 17 Time taken: 2.368564614094794
# sample no. : 18 Time taken: 2.502957816235721
# sample no. : 19 Time taken: 2.622951534576714
# sample no. : 20 Time taken: 2.74183935765177
# sample no. : 21 Time taken: 2.860814212821424
# sample no. : 22 Time taken: 2.9830540884286165
# sample no. : 23 Time taken: 3.106335706077516
# sample no. : 24 Time taken: 3.225741841830313
# sample no. : 25 Time taken: 3.3676398806273937
# sample no. : 26 Time taken: 3.4875400261953473
# sample no. : 27 Time taken: 3.6080269776284695
# sample no. : 28 Time taken: 3.7318447614088655
# sample no. : 29 Time taken: 3.8632453083992004
# sample no. : 30 Time taken: 3.985765607096255
# sample no. : 31 Time taken: 4.107132454402745
# sample no. : 32 Time taken: 4.2282219817861915
# sample no. : 33 Time taken: 4.35642574261874
# sample no. : 34 Time taken: 4.475887078791857
# sample no. : 35 Time taken: 4.597023406997323
# sample no. : 36 Time taken: 4.724731924943626
# sample no. : 37 Time taken: 4.844489425420761
# sample no. : 38 Time taken: 4.9659788412973285
# sample no. : 39 Time taken: 5.091251388192177
# sample no. : 40 Time taken: 5.219308078289032
# sample no. : 41 Time taken: 5.338176907040179
# sample no. : 42 Time taken: 5.460024937056005
# sample no. : 43 Time taken: 5.580296118743718
# sample no. : 44 Time taken: 5.7021347768604755
# sample no. : 45 Time taken: 5.840316048823297
# sample no. : 46 Time taken: 5.958677097223699
# sample no. : 47 Time taken: 6.078146083280444
# sample no. : 48 Time taken: 6.197990484535694
# sample no. : 49 Time taken: 6.317197353579104
# sample no. : 50 Time taken: 6.443880260922015
# sample no. : 51 Time taken: 6.565333876758814
# sample no. : 52 Time taken: 6.685641896910965
# sample no. : 53 Time taken: 6.804167444817722
# sample no. : 54 Time taken: 6.92303263489157
# sample no. : 55 Time taken: 7.041560961864889
# sample no. : 56 Time taken: 7.1694791205227375
# sample no. : 57 Time taken: 7.288325538858771
# sample no. : 58 Time taken: 7.420404781587422
# sample no. : 59 Time taken: 7.539954597130418
# sample no. : 60 Time taken: 7.663121582940221
# sample no. : 61 Time taken: 7.78520994912833
# sample no. : 62 Time taken: 7.903689523227513
# sample no. : 63 Time taken: 8.022328411228955
# sample no. : 64 Time taken: 8.146550577133894
# sample no. : 65 Time taken: 8.268930765800178
# sample no. : 66 Time taken: 8.40529028326273
# sample no. : 67 Time taken: 8.52809895761311
# sample no. : 68 Time taken: 8.649841574020684
# sample no. : 69 Time taken: 8.769410539418459
# sample no. : 70 Time taken: 8.89146681316197
# sample no. : 71 Time taken: 9.010419243946671
# sample no. : 72 Time taken: 9.163099985569715
# sample no. : 73 Time taken: 9.283015758730471
# sample no. : 74 Time taken: 9.40424352698028
# sample no. : 75 Time taken: 9.523674060590565
# sample no. : 76 Time taken: 9.651906642131507
# sample no. : 77 Time taken: 9.770400339737535
# sample no. : 78 Time taken: 9.888827052898705
# sample no. : 79 Time taken: 10.007719128392637
# sample no. : 80 Time taken: 10.130885526537895
# sample no. : 81 Time taken: 10.250808279961348
# sample no. : 82 Time taken: 10.37023991998285
# sample no. : 83 Time taken: 10.495679954066873
# sample no. : 84 Time taken: 10.616701639257371
# sample no. : 85 Time taken: 10.735953933559358
# sample no. : 86 Time taken: 10.855882248841226
# sample no. : 87 Time taken: 10.980977214872837
# sample no. : 88 Time taken: 11.109425698406994
# sample no. : 89 Time taken: 11.229018533602357
# sample no. : 90 Time taken: 11.347662832587957
# sample no. : 91 Time taken: 11.46664982009679
# sample no. : 92 Time taken: 11.588488492183387
# sample no. : 93 Time taken: 11.707656598649919
# sample no. : 94 Time taken: 11.825638708658516
# sample no. : 95 Time taken: 11.944409994408488
# sample no. : 96 Time taken: 12.065823680721223
# sample no. : 97 Time taken: 12.185415800660849
# sample no. : 98 Time taken: 12.30760461371392
# sample no. : 99 Time taken: 12.429187789559364
# sample no. : 100 Time taken: 12.551716246642172
# sample no. : 101 Time taken: 12.670764259062707
# sample no. : 102 Time taken: 12.791281130164862
# sample no. : 103 Time taken: 12.91244709212333
# sample no. : 104 Time taken: 13.034996419213712
# sample no. : 105 Time taken: 13.16300664562732
# sample no. : 106 Time taken: 13.291315336711705
# sample no. : 107 Time taken: 13.41294245608151
# sample no. : 108 Time taken: 13.55024089012295
# sample no. : 109 Time taken: 13.670839636586607
# sample no. : 110 Time taken: 13.791668825782835
# sample no. : 111 Time taken: 13.925123864784837
# sample no. : 112 Time taken: 14.044079730287194
# sample no. : 113 Time taken: 14.163229024969041
# sample no. : 114 Time taken: 14.282196843996644
# sample no. : 115 Time taken: 14.406963875517249
# sample no. : 116 Time taken: 14.528006486594677
# sample no. : 117 Time taken: 14.647482323460281
# sample no. : 118 Time taken: 14.767912657931447
# sample no. : 119 Time taken: 14.886877932585776
# sample no. : 120 Time taken: 15.02566279284656
# sample no. : 121 Time taken: 15.154200671240687
# sample no. : 122 Time taken: 15.27622361201793
# sample no. : 123 Time taken: 15.402505786158144
# sample no. : 124 Time taken: 15.559866111725569
# sample no. : 125 Time taken: 15.682694655843079
# sample no. : 126 Time taken: 15.802508127875626
# sample no. : 127 Time taken: 15.944176822900772
# sample no. : 128 Time taken: 16.06456465087831
# sample no. : 129 Time taken: 16.18428830895573
# sample no. : 130 Time taken: 16.30814086459577
# sample no. : 131 Time taken: 16.42736284341663
# sample no. : 132 Time taken: 16.54694725573063
# sample no. : 133 Time taken: 16.666048041544855
# sample no. : 134 Time taken: 16.791265826672316
# sample no. : 135 Time taken: 16.910250663757324
# sample no. : 136 Time taken: 17.028447661548853
# sample no. : 137 Time taken: 17.155993757769465
# sample no. : 138 Time taken: 17.282080210745335
# sample no. : 139 Time taken: 17.401174508035183
# sample no. : 140 Time taken: 17.5277194166556
# sample no. : 141 Time taken: 17.648544075898826
# sample no. : 142 Time taken: 17.771039394661784
# sample no. : 143 Time taken: 17.89167289249599
# sample no. : 144 Time taken: 18.02284571249038
# sample no. : 145 Time taken: 18.144010338932276
# sample no. : 146 Time taken: 18.264644182287157
# sample no. : 147 Time taken: 18.384848601184785
# sample no. : 148 Time taken: 18.506898446008563
# sample no. : 149 Time taken: 18.64771235920489
# sample no. : 150 Time taken: 18.773138277232647
# sample no. : 151 Time taken: 18.892560082487762
# sample no. : 152 Time taken: 19.013685040175915
# sample no. : 153 Time taken: 19.13936734572053
# sample no. : 154 Time taken: 19.26017714291811
# sample no. : 155 Time taken: 19.379142030142248
# sample no. : 156 Time taken: 19.497796680778265
# sample no. : 157 Time taken: 19.617260355502367
# sample no. : 158 Time taken: 19.74997961241752
# sample no. : 159 Time taken: 19.869527081027627
# sample no. : 160 Time taken: 19.989700644277036
# sample no. : 161 Time taken: 20.108779033645988
# sample no. : 162 Time taken: 20.23044938221574
# sample no. : 163 Time taken: 20.35116903297603
# sample no. : 164 Time taken: 20.469497893936932
# sample no. : 165 Time taken: 20.595503073185682
# sample no. : 166 Time taken: 20.72505055181682
# sample no. : 167 Time taken: 20.844413354992867
# sample no. : 168 Time taken: 20.97080455906689
# sample no. : 169 Time taken: 21.09583406895399
# sample no. : 170 Time taken: 21.223468684591353
# sample no. : 171 Time taken: 21.34440716728568
# sample no. : 172 Time taken: 21.466406472958624
# sample no. : 173 Time taken: 21.586925850249827
# sample no. : 174 Time taken: 21.708965013734996
# sample no. : 175 Time taken: 21.828360359184444
# sample no. : 176 Time taken: 21.948166114278138
# sample no. : 177 Time taken: 22.068639322184026
# sample no. : 178 Time taken: 22.18950146343559
# sample no. : 179 Time taken: 22.310636458918452
# sample no. : 180 Time taken: 22.431538993492723
# sample no. : 181 Time taken: 22.55319500528276
# sample no. : 182 Time taken: 22.672104231081903
# sample no. : 183 Time taken: 22.79296312201768
# sample no. : 184 Time taken: 22.912486504763365
# sample no. : 185 Time taken: 23.031290353275836
# sample no. : 186 Time taken: 23.158487303182483
# sample no. : 187 Time taken: 23.279688665643334
# sample no. : 188 Time taken: 23.39918085280806
# sample no. : 189 Time taken: 23.518416669219732
# sample no. : 190 Time taken: 23.640849057585
# sample no. : 191 Time taken: 23.781899840570986
# sample no. : 192 Time taken: 23.920642188750207
# sample no. : 193 Time taken: 24.040807142853737
# sample no. : 194 Time taken: 24.163862383924425
# sample no. : 195 Time taken: 24.28539194352925
# sample no. : 196 Time taken: 24.405811187811196
# sample no. : 197 Time taken: 24.52817859686911
# sample no. : 198 Time taken: 24.656366954557598
# sample no. : 199 Time taken: 24.776483581401408
# sample no. : 200 Time taken: 24.89928973093629
# this is s 64
# sample no. : 1 Time taken: 0.29600002709776163
# sample no. : 2 Time taken: 0.32518854923546314
# sample no. : 3 Time taken: 0.3754313373938203
# sample no. : 4 Time taken: 0.403945685364306
# sample no. : 5 Time taken: 0.43099152110517025
# sample no. : 6 Time taken: 0.458331317640841
# sample no. : 7 Time taken: 0.48553920444101095
# sample no. : 8 Time taken: 0.5145088937133551
# sample no. : 9 Time taken: 0.5422082943841815
# sample no. : 10 Time taken: 0.5695947362110019
# sample no. : 11 Time taken: 0.5968518909066916
# sample no. : 12 Time taken: 0.6238012360408902
# sample no. : 13 Time taken: 0.6508629387244582
# sample no. : 14 Time taken: 0.6793589740991592
# sample no. : 15 Time taken: 0.7063876669853926
# sample no. : 16 Time taken: 0.7390197245404124
# sample no. : 17 Time taken: 0.7672018520534039
# sample no. : 18 Time taken: 0.7943617822602391
# sample no. : 19 Time taken: 0.8213957445695996
# sample no. : 20 Time taken: 0.8488268265500665
# sample no. : 21 Time taken: 0.8761544367298484
# sample no. : 22 Time taken: 0.9035551371052861
# sample no. : 23 Time taken: 0.9313767235726118
# sample no. : 24 Time taken: 0.9641661886125803
# sample no. : 25 Time taken: 0.9972191723063588
# sample no. : 26 Time taken: 1.024708079174161
# sample no. : 27 Time taken: 1.052101094275713
# sample no. : 28 Time taken: 1.0793822249397635
# sample no. : 29 Time taken: 1.1066289125010371
# sample no. : 30 Time taken: 1.1341547025367618
# sample no. : 31 Time taken: 1.1661934657022357
# sample no. : 32 Time taken: 1.197986333630979
# sample no. : 33 Time taken: 1.2307302514091134
# sample no. : 34 Time taken: 1.2582267206162214
# sample no. : 35 Time taken: 1.2889412520453334
# sample no. : 36 Time taken: 1.321589802391827
# sample no. : 37 Time taken: 1.3483859421685338
# sample no. : 38 Time taken: 1.3753341799601912
# sample no. : 39 Time taken: 1.40241514518857
# sample no. : 40 Time taken: 1.434919753111899
# sample no. : 41 Time taken: 1.4692733604460955
# sample no. : 42 Time taken: 1.4962652791291475
# sample no. : 43 Time taken: 1.531902652233839
# sample no. : 44 Time taken: 1.559437739662826
# sample no. : 45 Time taken: 1.5870000282302499
# sample no. : 46 Time taken: 1.6143449125811458
# sample no. : 47 Time taken: 1.641526677645743
# sample no. : 48 Time taken: 1.6732247350737453
# sample no. : 49 Time taken: 1.7089950675144792
# sample no. : 50 Time taken: 1.735881612636149
# sample no. : 51 Time taken: 1.7629612889140844
# sample no. : 52 Time taken: 1.7901674369350076
# sample no. : 53 Time taken: 1.8169282041490078
# sample no. : 54 Time taken: 1.8447005497291684
# sample no. : 55 Time taken: 1.8722748393192887
# sample no. : 56 Time taken: 1.901304354891181
# sample no. : 57 Time taken: 1.937490968964994
# sample no. : 58 Time taken: 1.9654140081256628
# sample no. : 59 Time taken: 1.9927882086485624
# sample no. : 60 Time taken: 2.0204147594049573
# sample no. : 61 Time taken: 2.04764093644917
# sample no. : 62 Time taken: 2.0751615716144443
# sample no. : 63 Time taken: 2.1024670703336596
# sample no. : 64 Time taken: 2.1316317059099674
# sample no. : 65 Time taken: 2.1632836973294616
# sample no. : 66 Time taken: 2.1904128547757864
# sample no. : 67 Time taken: 2.217378167435527
# sample no. : 68 Time taken: 2.2443441646173596
# sample no. : 69 Time taken: 2.2717945855110884
# sample no. : 70 Time taken: 2.298989722505212
# sample no. : 71 Time taken: 2.326312929391861
# sample no. : 72 Time taken: 2.3561078319326043
# sample no. : 73 Time taken: 2.386229258030653
# sample no. : 74 Time taken: 2.41337497998029
# sample no. : 75 Time taken: 2.440223270095885
# sample no. : 76 Time taken: 2.4671731488779187
# sample no. : 77 Time taken: 2.494265384040773
# sample no. : 78 Time taken: 2.521593077108264
# sample no. : 79 Time taken: 2.5486060474067926
# sample no. : 80 Time taken: 2.5772717483341694
# sample no. : 81 Time taken: 2.608895132318139
# sample no. : 82 Time taken: 2.6357545321807265
# sample no. : 83 Time taken: 2.6631046812981367
# sample no. : 84 Time taken: 2.692684489302337
# sample no. : 85 Time taken: 2.720227108336985
# sample no. : 86 Time taken: 2.747365014627576
# sample no. : 87 Time taken: 2.7758652474731207
# sample no. : 88 Time taken: 2.806813928298652
# sample no. : 89 Time taken: 2.8375999443233013
# sample no. : 90 Time taken: 2.8647431805729866
# sample no. : 91 Time taken: 2.8917538337409496
# sample no. : 92 Time taken: 2.9202224696055055
# sample no. : 93 Time taken: 2.9471078952774405
# sample no. : 94 Time taken: 2.975015949457884
# sample no. : 95 Time taken: 3.0026922645047307
# sample no. : 96 Time taken: 3.032953202724457
# sample no. : 97 Time taken: 3.065960118547082
# sample no. : 98 Time taken: 3.0937614226713777
# sample no. : 99 Time taken: 3.121828987263143
# sample no. : 100 Time taken: 3.148767275735736
# sample no. : 101 Time taken: 3.182373506948352
# sample no. : 102 Time taken: 3.2282732017338276
# sample no. : 103 Time taken: 3.2576976269483566
# sample no. : 104 Time taken: 3.2860928485170007
# sample no. : 105 Time taken: 3.313343928195536
# sample no. : 106 Time taken: 3.3402788219973445
# sample no. : 107 Time taken: 3.3673598151654005
# sample no. : 108 Time taken: 3.394523223862052
# sample no. : 109 Time taken: 3.4217914436012506
# sample no. : 110 Time taken: 3.450036129914224
# sample no. : 111 Time taken: 3.481895588338375
# sample no. : 112 Time taken: 3.5216296147555113
# sample no. : 113 Time taken: 3.5484532536938787
# sample no. : 114 Time taken: 3.57551372051239
# sample no. : 115 Time taken: 3.6028146473690867
# sample no. : 116 Time taken: 3.629891648888588
# sample no. : 117 Time taken: 3.656530726701021
# sample no. : 118 Time taken: 3.684784833341837
# sample no. : 119 Time taken: 3.7136897295713425
# sample no. : 120 Time taken: 3.741204235702753
# sample no. : 121 Time taken: 3.7679948024451733
# sample no. : 122 Time taken: 3.795220922678709
# sample no. : 123 Time taken: 3.8225182127207518
# sample no. : 124 Time taken: 3.849444759078324
# sample no. : 125 Time taken: 3.8777038399130106
# sample no. : 126 Time taken: 3.904401183128357
# sample no. : 127 Time taken: 3.9357430581003428
# sample no. : 128 Time taken: 3.9704572232440114
# sample no. : 129 Time taken: 3.998206199146807
# sample no. : 130 Time taken: 4.025614546611905
# sample no. : 131 Time taken: 4.052489678375423
# sample no. : 132 Time taken: 4.079647016711533
# sample no. : 133 Time taken: 4.106666799634695
# sample no. : 134 Time taken: 4.134479723870754
# sample no. : 135 Time taken: 4.163403338752687
# sample no. : 136 Time taken: 4.198111725971103
# sample no. : 137 Time taken: 4.225553767755628
# sample no. : 138 Time taken: 4.2526665879413486
# sample no. : 139 Time taken: 4.279875588603318
# sample no. : 140 Time taken: 4.307432669214904
# sample no. : 141 Time taken: 4.33483318798244
# sample no. : 142 Time taken: 4.361585156992078
# sample no. : 143 Time taken: 4.395721488632262
# sample no. : 144 Time taken: 4.423546575941145
# sample no. : 145 Time taken: 4.451089011505246
# sample no. : 146 Time taken: 4.478225945495069
# sample no. : 147 Time taken: 4.505345372483134
# sample no. : 148 Time taken: 4.5327403312548995
# sample no. : 149 Time taken: 4.5595586420968175
# sample no. : 150 Time taken: 4.586637971922755
# sample no. : 151 Time taken: 4.618402558378875
# sample no. : 152 Time taken: 4.646303261630237
# sample no. : 153 Time taken: 4.674172600731254
# sample no. : 154 Time taken: 4.70137439109385
# sample no. : 155 Time taken: 4.728491413407028
# sample no. : 156 Time taken: 4.755623629316688
# sample no. : 157 Time taken: 4.782809362746775
# sample no. : 158 Time taken: 4.811147270724177
# sample no. : 159 Time taken: 4.843745230697095
# sample no. : 160 Time taken: 4.872827945277095
# sample no. : 161 Time taken: 4.900148603133857
# sample no. : 162 Time taken: 4.927561058662832
# sample no. : 163 Time taken: 4.9549410762265325
# sample no. : 164 Time taken: 4.982377733103931
# sample no. : 165 Time taken: 5.009750414639711
# sample no. : 166 Time taken: 5.037047203630209
# sample no. : 167 Time taken: 5.067605832591653
# sample no. : 168 Time taken: 5.101846176199615
# sample no. : 169 Time taken: 5.129305200651288
# sample no. : 170 Time taken: 5.156426134519279
# sample no. : 171 Time taken: 5.1832632860168815
# sample no. : 172 Time taken: 5.210979640483856
# sample no. : 173 Time taken: 5.238333683460951
# sample no. : 174 Time taken: 5.265592616982758
# sample no. : 175 Time taken: 5.294431230053306
# sample no. : 176 Time taken: 5.33071995805949
# sample no. : 177 Time taken: 5.358129313215613
# sample no. : 178 Time taken: 5.385999575257301
# sample no. : 179 Time taken: 5.413566226139665
# sample no. : 180 Time taken: 5.450251247733831
# sample no. : 181 Time taken: 5.477120514959097
# sample no. : 182 Time taken: 5.505129013210535
# sample no. : 183 Time taken: 5.543779918923974
# sample no. : 184 Time taken: 5.572009392082691
# sample no. : 185 Time taken: 5.599566449411213
# sample no. : 186 Time taken: 5.628007830120623
# sample no. : 187 Time taken: 5.657272940501571
# sample no. : 188 Time taken: 5.68604239821434
# sample no. : 189 Time taken: 5.713470441289246
# sample no. : 190 Time taken: 5.741736269555986
# sample no. : 191 Time taken: 5.777545156888664
# sample no. : 192 Time taken: 5.807993778027594
# sample no. : 193 Time taken: 5.836542489007115
# sample no. : 194 Time taken: 5.864589714445174
# sample no. : 195 Time taken: 5.892813669517636
# sample no. : 196 Time taken: 5.919917072169483
# sample no. : 197 Time taken: 5.947678522206843
# sample no. : 198 Time taken: 5.975119455717504
# sample no. : 199 Time taken: 6.0078611467033625
# sample no. : 200 Time taken: 6.037213832139969
